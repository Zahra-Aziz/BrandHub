# %%
import pymongo
from pymongo import MongoClient

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import nltk
from nltk.stem import PorterStemmer

# %%
titles=[]
text=[]
MenBrands=['Cambridge','Outfitters','Jdot'] #men brands
men_idx=[0,0,0] #to store indices of each male brand to display products from db after text search
WomenBrands=['Limelight','khaadi','sapphire','Outfitters','Jdot'] #women brands
women_idx=[0,0,0,0,0] ##to store indices of each female brand to display products from db after text search
client = pymongo.MongoClient("mongodb+srv://zahra:passmongodb@cluster0.femwg.mongodb.net/test?retryWrites=true&w=majority")

query = {'textSearch': {'$exists': 1}}
projection = {'_id': 0,'textSearch':1}

query1 = {'PId': {'$exists': 1}}
projection1 = {'_id': 0, 'PId': 1}


def ConvertToList(string): 
    li = list(string.split(" ")) 
    return li 

def TextSearchGender(gender): #this function returns textsearch for specified gender from db
    s=0 
    i=0
    titles=[]
    text=[]
    
    if (gender=='F'):
        brands=WomenBrands #if gender is female, only select female brands
        idx_array=women_idx #index array for storing indices of female brands that will be used later on to retriev products from db
        gen="Women"
    else:
        brands=MenBrands #if gender is male, only select male brands
        idx_array=men_idx #index array for storing indices of male brands that will be used later on to retriev products from db
        gen="Men"
    print(brands)
    s=0 
    i=0
    id_count=0
    for b in brands:
        brand=b
        
        #store the starting index(i) for each brand in the idx_array 
        if (brand==brands[0]):
            idx_array[0]=i
        elif (brand==brands[1]):
            idx_array[1]=i
        elif (brand==brands[2]):
            idx_array[2]=i

        elif (gender=='F'):
            if (brand==brands[3]):
                idx_array[3]=i
            elif (brand==brands[4]):
                idx_array[4]=i

        db=client[brand] #get specific brand from db
        db_collection=db[gen] #get specific gender of brand from db
 

        desc = list(db_collection.find(query, projection)) #all products from db in list form
        idd = list(db_collection.find(query1, projection1)) #IDs of all products from db in list form
        
        id_count=0
        for message in desc:
            for key, value in message.items():
                text.append(value) #store the textsearch data in text array
            i+=1
            id_count+=1
#         print(id_count)

        k=0    
        for dat in idd:
            for key,value in dat.items():
                titles.append(value) #store the IDs of products in titles array
            if (k==id_count-1): #to ensure that text and titles have same length
                break;
            k+=1
            
    return (text,titles,idx_array,brands) #return data,IDs, index array and brands to be used later on

    
def TextSearch(inputText,searchText,titles,gender,array_idx,brands): #this function computes the textual search and retrieves results of search from db
    product_count=1 #for storing products in dictionary
    choices_dict = {idx: el for idx, el in enumerate(searchText)} #converts data to dictionary
    choices_titles = {idx: el for idx, el in enumerate(titles)} ##converts titles to dictionary
    fromdocs=process.extract(inputText, choices_dict,scorer=fuzz.token_set_ratio,limit=30) #apply fuzzy search. get Maximum of 30 products
#     print(process.extract(inputText, choices_dict,scorer=fuzz.token_set_ratio,limit=30))
  
#     print(array_idx)
    number=0
    dict1={}
    product={}
    LenArray=len(array_idx) #this tells us the total brands we'll be iterating. 3 for men. 5 for women
    for i in range (len(fromdocs)):
        number=fromdocs[i][2] #stores the index of resultant textSearch product
        accuracy=fromdocs[i][1] #stores accuracy of resultant textSearch product
#         print(str(number)+gender)

        #specify which index(number) does the product belong to and get relevant brand from db
        if (number>=array_idx[LenArray-1]):
            db=client[brands[LenArray-1]] 

        elif (number>=array_idx[LenArray-2]):
            db=client[brands[LenArray-2]]

        elif (number>=array_idx[LenArray-3]):
            db=client[brands[LenArray-3]]

        #women have 5 brands so 2 extra checks for brands if gender is women
        elif (gender=='Women'):
            if (number>=array_idx[LenArray-4]):
                db=client[brands[LenArray-4]]

            elif (number>=array_idx[LenArray-5]):
                db=client[brands[LenArray-5]]
        
        db_collection=db[gender] #after getting specific brand, get specific gender of that brand
        product=db_collection.find_one({'PId': titles[number]}) #get data from db
        
        
#         print(titles[number])


        prod={} #will contain each individual product
        if (product!=None): 
            for key,val in product.items():
                if (key!='featureVectors' and key!='textSearch' and accuracy>65): #add every other value except for these in our prod dictionary and only if accuracy of search result is greater than 65
                    prod[key]=val
#                 if (key!='featureVectors' and accuracy>65):
#                     print(str(key)+ " : "+str(val))
            

        if (len(prod)!=0): #if product exists, only then add in dict1(all products)
            dict1[product_count]=prod
            product_count+=1
           
    return dict1 #returns dictionary containing all products of text search

# %%
Data=[] #to store all data from db
IDs=[] #to store ids of products from db
idx_arr=[] #to store indices of each brand to display products from db after text search. size will be 3 if men search and 5 if women search
Brnads=[]

MenBrands=['Cambridge','Outfitters','Jdot'] #men brands
men_idx=[0,0,0] #to store indices of each male brand to display products from db after text search
WomenBrands=['Limelight','khaadi','sapphire','Outfitters','Jdot'] #women brands
women_idx=[0,0,0,0,0] ##to store indices of each female brand to display products from db after text search


s=0
i=0

gender = input("Enter F to search from Female Section and M to search Male section: ") #store gender of search
(Data,IDs,idx_arr,Brands)=TextSearchGender(gender) #this function gets the data from db for the spcified gender

val= input("What do you want to search:") #store what u want to search


#perform stemming on input data to achieve good results
ps = PorterStemmer()
arr=ConvertToList(val) #convert user input to list
inputsearch=""
for v in arr:
    inputsearch+=ps.stem(v) #perform stemming
    inputsearch+=" "

#specify the gender
if (gender=='F'):
    gender="Women"
else:
    gender="Men"


titles=[]
data=[]
AllProducts={}
AllProducts=TextSearch(inputsearch,Data,IDs,gender,idx_arr,Brands) #perform textual search on the input

for key,value in AllProducts.items():
    print(str(key)+": ")
    print(value)

# print(len(titles))
# print(len(text))
# print(len(idx_arr))
# Out:
# Enter F to search from Female Section and M to search Male section: M
# ['Cambridge', 'Outfitters', 'Jdot']
# What do you want to search:polo shirt
# 1:
# {'_id': ObjectId('5fd398fb541eec7b279fa344'), 'PId': 'OM_316_', 'PName': 'Embroidered Logo Polo Shirt', 'PPrice': 'PKR 1,590', 'OnSale': False, 'SPrice': '', 'Color': 'WHT', 'Link': 'https://outfitters.com.pk/collections/new-men/products/mtc201069wht', 'Fabric': '', 'Description': '', 'Type': '', 'ImageName': ['https://drive.google.com/file/d/1SdA3w9Hc2WB6xJMxIXg2TG6bJXxwQZrt/view', 'https://drive.google.com/file/d/1Jy6C4nclEu9eUj_rCiDUwAUOI8MAlz0q/view']}
# 2:
# {'_id': ObjectId('5fd39dd3541eec7b279fa373'), 'PId': 'OM_362_', 'PName': 'Embroidered Logo Polo Shirt', 'PPrice': 'PKR 1,590', 'OnSale': False, 'SPrice': '', 'Color': 'BLK', 'Link': 'https://outfitters.com.pk/collections/new-men/products/mtc201069blk', 'Fabric': '', 'Description': '', 'Type': '', 'ImageName': ['https://drive.google.com/file/d/1cVojJjTDAwqCQsW76EghBaBa8Jrz4HY7/view']}
# 3:
# {'_id': ObjectId('5fd1fef28e01020def3b6c3f'), 'PId': 'CM_1_', 'PName': 'UNTUCKED CAMBRIDGE', 'PPrice': 'Rs.2,795.00', 'OnSale': True, 'SPrice': 'Rs.2,236.00', 'Color': 'sky-blue-stripe', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b5964', 'Fabric': '100% Cotton', 'Description': 'Designed to be worn untucked - Full sleeves slim fit shirt', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1goPWRcA_weGm0pADpJotbxQF_tKbdM6D/view', 'https://drive.google.com/file/d/1iNDe4PGdgJu7YAE5Op6pwjZZnDthNVZd/view', 'https://drive.google.com/file/d/1PIMlkcWAXtXOjWpLogygBTIcz9uiWA3M/view', 'https://drive.google.com/file/d/11tmrgORWdZl2W1TT9sP6hZTl7I4avzYw/view', 'https://drive.google.com/file/d/13W0FW6eNIsL3H1K6U2O-t7IKXmpfxPcV/view', 'https://drive.google.com/file/d/1U1Gl6N8ZLZMomBQTquHEMLI4Jb3t7D_8/view', 'https://drive.google.com/file/d/16gF0Z839fBo7Y3moqTd8o0dbLvFME9vh/view']}
# 4:
# {'_id': ObjectId('5fd1ff0d8e01020def3b6c40'), 'PId': 'CM_2_', 'PName': 'UNTUCKED CAMBRIDGE', 'PPrice': 'Rs.2,795.00', 'OnSale': False, 'SPrice': '', 'Color': 'off-white-plaid', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b6002s', 'Fabric': '100% Cotton', 'Description': 'Designed to be worn untucked - Full sleeves slim fit shirt', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1vj3ByxqqW9sxOWVRSCgzd3BbF-0rnLoK/view', 'https://drive.google.com/file/d/1STVRVcCygQXowUbUeD7UGtumuKE2p2As/view', 'https://drive.google.com/file/d/1bUC5HHCCe1Amjy-c71tG-sQfqivFE8_h/view', 'https://drive.google.com/file/d/1qMTf45q7QFRZNsoqyIvyb8y41XH1UnJk/view', 'https://drive.google.com/file/d/1YbRiC1qsJaSqUULtILYIUtHFRj9dSBB6/view', 'https://drive.google.com/file/d/1d3asAIumEeTX9zDNBmcdgAwEG-i_cdjA/view', 'https://drive.google.com/file/d/1HGOM6CZZUKMqDhnwoevPkpTIhxe0ewaH/view']}
# 5:
# {'_id': ObjectId('5fd1ff2d8e01020def3b6c41'), 'PId': 'CM_3_', 'PName': 'UNTUCKED CAMBRIDGE', 'PPrice': 'Rs.2,795.00', 'OnSale': False, 'SPrice': '', 'Color': 'mid-blue-plaid', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b6000s', 'Fabric': '100% Cotton', 'Description': 'Designed to be worn untucked - Full sleeves slim fit shirt', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1l3SvoMF3O852xYxI_rqdEuyU1TFdEj1T/view', 'https://drive.google.com/file/d/1hmw4arJPFkHvOU7YdqreYhTjrWDLrOyq/view', 'https://drive.google.com/file/d/1w2P2QMx4id--Y8GsWFD4uRHiPNV-Dz_U/view', 'https://drive.google.com/file/d/1aDsj-M7i6Y9wMkSXingofa654jXOKfUc/view', 'https://drive.google.com/file/d/1PtAIBi4kxucaZHUKTkIFgPOWXhrQETrU/view', 'https://drive.google.com/file/d/1IekNE7XK1eB4CExVBAi_wTSyYdp38EXX/view', 'https://drive.google.com/file/d/1l8IN49PU1oeYdZZWN8g9SGieQxXcz-Ou/view']}
# 6:
# {'_id': ObjectId('5fd1ff418e01020def3b6c42'), 'PId': 'CM_4_', 'PName': 'UNTUCKED CAMBRIDGE', 'PPrice': 'Rs.2,795.00', 'OnSale': False, 'SPrice': '', 'Color': 'navy-green-atlas-check', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b6001s', 'Fabric': '100% Cotton', 'Description': 'Designed to be worn untucked - Full sleeves slim fit shirt', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/10eBIrJbYpLWqMEIgD-g5RmEY3bSElBIA/view', 'https://drive.google.com/file/d/1MsKE3I2WYNu0lk79GlcqNkJwB5v3HzT-/view', 'https://drive.google.com/file/d/1OFAYwO9YJ7OoY8S7TxJ-2eB6vRDjfBaZ/view', 'https://drive.google.com/file/d/1WqiDWxPHwf2Itzl8S4JL8avOnyw-CrNV/view']}
# 7:
# {'_id': ObjectId('5fd1ff6c8e01020def3b6c43'), 'PId': 'CM_5_', 'PName': 'ZERQ - Regular Fit', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.2,156.00', 'Color': 'blue-white-nickel-check', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-zerq-b5992s', 'Fabric': '100% Cotton', 'Description': 'Full sleeves ZERQ is a light weight fabric made of using combed cotton yarn with crisp finish for daily wear....', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1khN6a-7zr0QbqXnKx62cuIlQqhfyuW4a/view', 'https://drive.google.com/file/d/1z-Tmq05e8IAqkLPrVhrijQgG-IfLA9wP/view', 'https://drive.google.com/file/d/1NCdoAkMp4h9kwG-cb2IvHgRFe0i_wNWe/view', 'https://drive.google.com/file/d/1jriY19k8aFN7slUCZEtB_PKBECI5Z2G6/view', 'https://drive.google.com/file/d/1KyKbNUH1YeM3_2pRhHvr8g9hRl4QwGMw/view', 'https://drive.google.com/file/d/12n2WV59PtGTfxdkYGeHBbjPSe-eRXTxY/view', 'https://drive.google.com/file/d/1MIb2aPcSZI1aIP6Y5nkg9oulgPkP0p-0/view']}
# 8:
# {'_id': ObjectId('5fd1ff828e01020def3b6c44'), 'PId': 'CM_6_', 'PName': 'F/S UNTUCKED CAMBRIDGE', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.2,156.00', 'Color': 'NAVY', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b5999', 'Fabric': '100% Cotton, Garment Dyed shirt', 'Description': '', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1nxlstixx6mIisYXIQZIvUtmv_KQ2IABx/view', 'https://drive.google.com/file/d/1TQrvlLhCFbMx9FmgnkHyexf1ZB0IDBgG/view', 'https://drive.google.com/file/d/1rf2K1DgznFLHhfxcuXg8lU-gXDXdpb8Q/view', 'https://drive.google.com/file/d/1mLxMO-CajUhGe3Zpw6v62Vyz2M5Rlee6/view']}
# 9:
# {'_id': ObjectId('5fd1ffa78e01020def3b6c45'), 'PId': 'CM_7_', 'PName': 'ZERQ - Slim Fit', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.2,156.00', 'Color': 'purple-green-plaid', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-zerq-b5990s', 'Fabric': '100% Cotton', 'Description': 'Full Sleeves ZERQ is a lightweight fabric made of using combed cotton yarn with crisp finish for daily wear', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1492L4hdd2-IDpw42Ndeebjc03k4j7fkL/view', 'https://drive.google.com/file/d/16MPTDy1s309HEJpypY7WI0nCRaQuwSiH/view', 'https://drive.google.com/file/d/1d-1Ye0mC1E91uxvb1w87doPDqRH5wLYE/view', 'https://drive.google.com/file/d/1XM1kXQqQ4OhsRs3BMjGTOGoRp3kRynhh/view', 'https://drive.google.com/file/d/1jlc2RFZbb9e_ueYjkyUQoAp819sbxLtP/view', 'https://drive.google.com/file/d/1gWgyDV-81J4DiBALiVPiaspfxc70jilX/view', 'https://drive.google.com/file/d/1_r69qHgm0ihg6Rt9QLv71QBMjvabFBsg/view']}
# 10:
# {'_id': ObjectId('5fd1ffc78e01020def3b6c46'), 'PId': 'CM_8_', 'PName': 'UNTUCKED CAMBRIDGE', 'PPrice': 'Rs.2,795.00', 'OnSale': True, 'SPrice': 'Rs.2,236.00', 'Color': 'solid-light-blue', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b5967', 'Fabric': '100% Cotton', 'Description': 'Designed to be worn untucked - Full sleeves slim fit shirt', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1rOwINo-JZrydDWsa7hJmReHXV5PFK8Ub/view', 'https://drive.google.com/file/d/1DLMwq0ai9DjS05HU6qVq6XEBVZggAzle/view', 'https://drive.google.com/file/d/196x0btaqJV03VfxY9mOXG0iSn67lqzIp/view', 'https://drive.google.com/file/d/1G4-m3Fi6QaNwi4-ltJlKA5vE3Ow-OtSG/view', 'https://drive.google.com/file/d/1MrMSh9KKu-aoKR-Ih7VtvYSOs5OJYaCW/view', 'https://drive.google.com/file/d/1WOu9jPiDG7QeT--DFYQFfzvovB7KoFIW/view']}
# 11:
# {'_id': ObjectId('5fd1ffd68e01020def3b6c47'), 'PId': 'CM_9_', 'PName': 'ZERQ - Comfort Fit', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.2,156.00', 'Color': 'blue-white-verdel-stripe', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-zerq-b5991c', 'Fabric': '100% Cotton', 'Description': 'Full Sleeves ZERQ is a lightweight fabric made of using of combed cotton yarn with crisp finish for daily wear....', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1vHvcc9f4GZRYqmtkoc2fQFq-yktDjR8Z/view', 'https://drive.google.com/file/d/1STkHhc1MjxLAinDXo5yY9y95rBNUaEbn/view', 'https://drive.google.com/file/d/1h70xIiGFkbrvmaqpMPF2jDszh8yxgqqk/view']}
# 12:
# {'_id': ObjectId('5fd1ffef8e01020def3b6c48'), 'PId': 'CM_10_', 'PName': 'F/S UNTUCKED - GARMENT DYED', 'PPrice': 'Rs.2,695.00', 'OnSale': False, 'SPrice': '', 'Color': 'WHITE', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b5999-white', 'Fabric': '100% Cotton, Garment Dyed shirt', 'Description': '', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1dqOeidmo2lYJGIOPE02mkhjbAksKBi6t/view', 'https://drive.google.com/file/d/1619ZuVnbejQ1aIT8qHK3oXANMjDawc5_/view', 'https://drive.google.com/file/d/1MTxPYzDA3s1LrRltKRDkNsvUC2I3ykVO/view', 'https://drive.google.com/file/d/1zpYFD_KMXW6DhEluP6ZTP1VM1FfOOqvP/view', 'https://drive.google.com/file/d/1Pr7J8bnxF1Bmmr40iQlYIHTRr9QyVaYo/view', 'https://drive.google.com/file/d/1n0-W9SpnMqkXcEfbXB5QECdVXOxUCYQ0/view', 'https://drive.google.com/file/d/1Y3lMR-iMqwFVdycPzu-dys3ilGiWA6ae/view']}
# 13:
# {'_id': ObjectId('5fd1ffff8e01020def3b6c49'), 'PId': 'CM_11_', 'PName': 'UNTUCKED CHECK SHIRTS', 'PPrice': 'Rs.2,795.00', 'OnSale': False, 'SPrice': '', 'Color': 'NAVY', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b6003s', 'Fabric': '100% Cotton', 'Description': '', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1vmHQa8cPfC6fVtkgI4HXW8kxSQMEGy5v/view', 'https://drive.google.com/file/d/1sBJm0ouUbkzF8dOPcHrOqkNBLXNW2vf2/view', 'https://drive.google.com/file/d/1_mCgR0pdjoXjOsjfYxqEVQOyMh4LmLtK/view']}
# 14:
# {'_id': ObjectId('5fd2001d8e01020def3b6c4a'), 'PId': 'CM_12_', 'PName': 'ZERQ', 'PPrice': 'Rs.2,895.00', 'OnSale': True, 'SPrice': 'Rs.2,316.00', 'Color': 'pink-white-mini-check', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-zerq-b5969s', 'Fabric': '100% Cotton', 'Description': 'Full Sleeves ZERQ is a lightweight fabric made of using combed cotton yarn with crisp finish for daily wear.', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1PhCRmJqU_ZiO6oIoc7LUS3Dx-jVKnTjW/view', 'https://drive.google.com/file/d/1A2Fe8BZmeJzve-WKn2x9GJLQ16hbyU7u/view', 'https://drive.google.com/file/d/1Vt7NAwI4FEV0rPBL5lF2GKhfFvgvCHcU/view', 'https://drive.google.com/file/d/16cTb5Ha1J2dJI7e-qam4OH75UX7gnzpB/view', 'https://drive.google.com/file/d/1NYs97mfhLA21YaqNG7ehjp6dw4ZhPGvS/view', 'https://drive.google.com/file/d/1uzqzoWoM-cY8XUscd-k40uIuOK7zD9EO/view']}
# 15:
# {'_id': ObjectId('5fd2002c8e01020def3b6c4b'), 'PId': 'CM_13_', 'PName': 'UNTUCKED - GARMENT DYED', 'PPrice': 'Rs.2,695.00', 'OnSale': False, 'SPrice': '', 'Color': 'NAVY', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b5999-navy', 'Fabric': '100% Cotton, Garment Dyed shirt', 'Description': 'Designed to be worn untucked. Garment dyed casual shirt full sleeves slim fit', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1pwNQBU6xBY2Vsz0KG7iFePTNqtZENggb/view', 'https://drive.google.com/file/d/1sbZgJuiiHtvZsupTqplTYx3fw2kwunlX/view', 'https://drive.google.com/file/d/16C5hCGA4s9sN8-KAH3vrIu8xfmMJwY_i/view', 'https://drive.google.com/file/d/1lR-Pas9FAfdCLmFswSmL55b30xf1XjvX/view']}
# 16:
# {'_id': ObjectId('5fd200548e01020def3b6c4c'), 'PId': 'CM_14_', 'PName': 'ZERQ CHECK SHIRTS', 'PPrice': 'Rs.2,895.00', 'OnSale': True, 'SPrice': 'Rs.2,316.00', 'Color': 'SKY BLUE', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-zerq-b6004c', 'Fabric': '100% Cotton', 'Description': '', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1ENSQKqtgEuAbqm7Q-3sR_8dsMnLnHyW9/view', 'https://drive.google.com/file/d/1k-O2TWfF31vsSAj_g_llbrII3CIWOj0A/view', 'https://drive.google.com/file/d/1RutvH3xc6ExmhhjGR9ZmcrUiEWI6MikB/view', 'https://drive.google.com/file/d/141YlB75j3G0gu4VYzXGWXGN2mEVekGRm/view', 'https://drive.google.com/file/d/1oM23G8gZET5MUaqZI5w9V3VrNn3nbiC3/view', 'https://drive.google.com/file/d/1dKHIa1J-VxWC-urxgBWkEkxNp0BEW-B-/view', 'https://drive.google.com/file/d/1zvwEET0gWRCSKcY8NKrG4Wwlmw08vpHX/view', 'https://drive.google.com/file/d/1lqJLhxGBojuWqtjgdxkYbwNdNY8dEHHZ/view', 'https://drive.google.com/file/d/1jXRU8NhsclpPNKm-eIKcnCfVWOSxPfGt/view']}
# 17:
# {'_id': ObjectId('5fd2006f8e01020def3b6c4d'), 'PId': 'CM_15_', 'PName': 'H/S LICENSE SHIRT', 'PPrice': 'Rs.2,494.00', 'OnSale': True, 'SPrice': 'Rs.1,496.40', 'Color': 'BLUE/WHITE', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/h-s-license-shirt-b5899s', 'Fabric': '100% Cotton', 'Description': '', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/17yzkpLkBlFfuBNMO0Xa8x8pdpUVTMIe6/view', 'https://drive.google.com/file/d/1hBvYraBIx1QJmolZfM5CN-ZDDSnQf2xQ/view', 'https://drive.google.com/file/d/1NPLZUQU19VvEl8e4WApXv98Dw4uQczWC/view', 'https://drive.google.com/file/d/11COFY1i9J3pVJ1Wfba7mT-m23fWgCz9g/view', 'https://drive.google.com/file/d/1U3HbtUer8h_Ssf5_L6OBoifQwLpEKtvk/view']}
# 18:
# {'_id': ObjectId('5fd200818e01020def3b6c4e'), 'PId': 'CM_16_', 'PName': 'UNTUCKED- Slim Fit', 'PPrice': 'Rs.2,795.00', 'OnSale': True, 'SPrice': 'Rs.2,236.00', 'Color': 'grey-white-stripe', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b5963', 'Fabric': '100% Cotton', 'Description': 'Designed to be worn untucked - Full sleeves slim fit shirt', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1mTvHPZatZhj9xOp2P8ikzocxgvk0cpsG/view', 'https://drive.google.com/file/d/1WCTz1ctC9SkDTQ2W9Q8ryxtNEXlkSepE/view', 'https://drive.google.com/file/d/1HpX59lhH5MowT7vkFO7t0ZyPOIevFGfo/view']}
# 19:
# {'_id': ObjectId('5fd200a48e01020def3b6c4f'), 'PId': 'CM_17_', 'PName': 'ZERQ - Slim Fit', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.2,156.00', 'Color': 'light-blue', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-zerq-b5988s', 'Fabric': '100% Cotton', 'Description': 'Full Sleeves ZERQ is a lightweight fabric made of using combed cotton yarn with crisp finish for daily wear', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1DjS8bH3c3yI7GekFZ18Q16oIGCkP7cx6/view', 'https://drive.google.com/file/d/14MXosevmSDwdbZzovTDpjnBrcCHn4Uwo/view', 'https://drive.google.com/file/d/1rf69xfWzOWpLX7Uru2dgiSTrCMAa4WtH/view', 'https://drive.google.com/file/d/1TygRulMKCq2o51QuQGXtI8RpySoXlb4X/view', 'https://drive.google.com/file/d/1eymcL1h8_cOioSZoAyTBYZSj1AutmkRF/view', 'https://drive.google.com/file/d/1Uso8uOwFnVIUYPsjHelZZmkt3FstZHM1/view']}
# 20:
# {'_id': ObjectId('5fd200bf8e01020def3b6c50'), 'PId': 'CM_18_', 'PName': 'ZERQ - Regular Fit', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.1,617.00', 'Color': 'sky-blue-plaid', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/h-s-zerq-b5998', 'Fabric': '100% Slub-Cotton', 'Description': 'Half Sleeves Zerq is a lightweight fabric made of using combed cotton yarn with crisp finish for daily wear.', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1NvXmtjdHNIybKOmkP6lRm8_tVpyY3R6v/view', 'https://drive.google.com/file/d/1Cz2z-gmycfGYXqNlad1nND__N4NeFqV7/view', 'https://drive.google.com/file/d/1rbqNtw_dfQnw7Yv9AR0iAyO6pmq82eLi/view', 'https://drive.google.com/file/d/18rlwgVOA2RD2d_0b1XwWglJmg0Qw06bu/view', 'https://drive.google.com/file/d/1SWqJDJljSn7rrATQlNs649sWplclj-nC/view', 'https://drive.google.com/file/d/1ggnuXJUxj1g_foiJmAN7llv_Onw4Ww-r/view']}
# 21:
# {'_id': ObjectId('5fd2026c8e01020def3b6c52'), 'PId': 'CM_19_', 'PName': 'ZERQ - Regular Fit', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.1,617.00', 'Color': 'greenwood-plaid', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/h-s-zerq-b5997', 'Fabric': '100% Slub-Cotton', 'Description': 'Half Sleeves ZERQ is a lightweight fabric made of using combed cotton yarn with crisp finish for daily wear.', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1FNNrdcMD9IisZl7I2iL8k6xYxHQJVAwT/view', 'https://drive.google.com/file/d/1sJpZDS2mLLIJbkCt--F1Un8nvW-dOQUo/view', 'https://drive.google.com/file/d/1wqR-51Q7SHWaiejwrsz3KTO6tIleMFwe/view', 'https://drive.google.com/file/d/1JMEmxVWTIUt2uVLdvavlf0DP19cGqwbk/view', 'https://drive.google.com/file/d/1-YtQBqxk5mrU6ihOyt8BsOiyjol0gD9d/view', 'https://drive.google.com/file/d/1Xcdd_XlQx7bvDT9sg97FUuYzriJniwYx/view']}
# 22:
# {'_id': ObjectId('5fd2027d8e01020def3b6c53'), 'PId': 'CM_20_', 'PName': 'ZERQ - Regular Fit', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.1,617.00', 'Color': 'aqua-white-plaid', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/h-s-zerq-b5996', 'Fabric': '100% Slub-Cotton', 'Description': 'Half Sleeves ZERQ is a lightweight fabric made of using combed cotton yarn with crisp finish for daily wear.', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1LGUaRWEoTEJcuq9m-rfIqZCV-bAR8BV8/view', 'https://drive.google.com/file/d/1el9-C9BiUujjbMamrQBJAqKuBXKQX109/view', 'https://drive.google.com/file/d/1bNryb0pnTayQ5wiBJ5MtnTTMV6T6lamc/view', 'https://drive.google.com/file/d/1fjWwTdRC_vwjxJs6f8fBafa517OYJikf/view']}
# 23:
# {'_id': ObjectId('5fd202908e01020def3b6c54'), 'PId': 'CM_21_', 'PName': 'ZERQ- Regular Fit', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.1,617.00', 'Color': 'light-blue-check', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/h-s-zerq-b5995', 'Fabric': '100% Slub-Cotton', 'Description': 'Half Sleeves ZERQ is a lightweight fabric made of using combed cotton yarn with crisp finish for daily wear.', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1RPrQ1cfop7Ly-q42GLh7Ygco5GkwEnfU/view', 'https://drive.google.com/file/d/1QV9Jsv0k9sYUgUxu32ml8K3GK8pqj6kf/view', 'https://drive.google.com/file/d/1WzaTW5WAC9_cAxVM6i2lVE0sL3Sp3VKg/view', 'https://drive.google.com/file/d/10NRrcCVk4jvJLet3q15_xrSX9vcGzmfW/view', 'https://drive.google.com/file/d/1-XJYV0zrmQnwIRYNeKBLTKIQyx-Isoi9/view']}
# 24:
# {'_id': ObjectId('5fd202a08e01020def3b6c55'), 'PId': 'CM_22_', 'PName': 'H/S ZERQ', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.1,617.00', 'Color': 'L/BLUE STRIPE', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/h-s-zerq-b5956c', 'Fabric': '100% Cotton', 'Description': '', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1JH_YaltlMJMLmjyKICXqT65g1kORoWzC/view', 'https://drive.google.com/file/d/1uXuQb82e9Gm6P3JtDYwekbSuy-epAf8o/view', 'https://drive.google.com/file/d/1DO3tfauST29cPz45_dqfp1ivV1hOMrUw/view', 'https://drive.google.com/file/d/13ni4qG1ON3MGnp6CRNKYCInlBZVCgGpD/view']}
# 25:
# {'_id': ObjectId('5fd202af8e01020def3b6c56'), 'PId': 'CM_23_', 'PName': 'H/S ZERQ', 'PPrice': 'Rs.2,695.00', 'OnSale': True, 'SPrice': 'Rs.1,617.00', 'Color': '', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/h-s-zerq-b5954c', 'Fabric': '', 'Description': '', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1vlC5_Fo7DJ4Bsqb6lkLhg8BMU649BAzs/view', 'https://drive.google.com/file/d/1mTmqkh2RVyebjSIw7HZcscyAj7zZWRpt/view', 'https://drive.google.com/file/d/1ryY9Ku_AVzIwDofpTvKXA74ZXnD8xMgj/view', 'https://drive.google.com/file/d/1uBgOIJNjlCo9SybY1uJtn3J-bb5NEa09/view']}
# 26:
# {'_id': ObjectId('5fd202bf8e01020def3b6c57'), 'PId': 'CM_24_', 'PName': 'ZERQ - Comfort Fit', 'PPrice': 'Rs.2,695.00', 'OnSale': False, 'SPrice': '', 'Color': 'mason-white', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-zerq-b5987c', 'Fabric': '100% Cotton', 'Description': 'Full Sleeves ZERQ is a lightweight dobby fabric made of combed cotton yarn with crisp finish for daily wear.', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1LqmXhGO-Xdl6LfBqET_uLz28hTuNj7wD/view', 'https://drive.google.com/file/d/1tL9FF8nfYDmFr60iuDoZEZqd5I5SheOj/view', 'https://drive.google.com/file/d/1u6zjxVdmjOMVnORJhwrSFc1kxBEnqWBI/view', 'https://drive.google.com/file/d/1nP_HM5XAkutZh9HC72hgH4tiE_WFqNfv/view']}
# 27:
# {'_id': ObjectId('5fd202ca8e01020def3b6c58'), 'PId': 'CM_25_', 'PName': 'F/S UNTUCKED - GARMENT DYED', 'PPrice': 'Rs.2,695.00', 'OnSale': False, 'SPrice': '', 'Color': 'BLACK', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b5999-black', 'Fabric': '100% Cotton, Garment Dyed shirt', 'Description': '', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/18XxgiWJ02zckBdkBcLANz0pZM_dKx0gf/view', 'https://drive.google.com/file/d/1M-jX8BXxh3yRaKhIRmnCGDt5qi-z_93R/view', 'https://drive.google.com/file/d/1SBPouZJhrE7K-HaQYa7MtgJxgm4b-Gni/view']}
# 28:
# {'_id': ObjectId('5fd202d78e01020def3b6c59'), 'PId': 'CM_26_', 'PName': 'ZERQ - Comfort Fit', 'PPrice': 'Rs.2,695.00', 'OnSale': False, 'SPrice': '', 'Color': 'sky-blue-stripe', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-zerq-b5986c', 'Fabric': '100% Cotton', 'Description': 'F/S ZERQ is a lightweight\xa0 pin stripe design made using of combed cotton yarn with crisp finish for daily wear....', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1-PzNnMybdTyGeVB7LGd0bAzeU1KvpKq9/view', 'https://drive.google.com/file/d/1dE1g9RIzaaP3f09qTO0xp4vYeYc9-8rQ/view', 'https://drive.google.com/file/d/1TackEp9ZxWsTealdL2e7vJgRgXaP-FH1/view']}
# 29:
# {'_id': ObjectId('5fd202e88e01020def3b6c5a'), 'PId': 'CM_27_', 'PName': 'UNTUCKED - Slim Fit', 'PPrice': 'Rs.2,795.00', 'OnSale': True, 'SPrice': 'Rs.2,236.00', 'Color': 'sky-white-plaid', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b5962', 'Fabric': '100% Cotton', 'Description': 'Designed to be worn untucked - Full sleeves slim fit shirt', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1qrNfZsrW9ie8N1dgiCZGIBdbSJcIlXIR/view', 'https://drive.google.com/file/d/18BRlgq-MskDq_yVL-qQqcyBz96jFyflv/view', 'https://drive.google.com/file/d/1KD4Lwj-Vnl2aB_eXbUZKDydhW8MR_g4Q/view', 'https://drive.google.com/file/d/1gpeUM54c6Ic7tjPjBFv2S9mY1KWYv55J/view']}
# 30:
# {'_id': ObjectId('5fd202fa8e01020def3b6c5b'), 'PId': 'CM_28_', 'PName': 'UNTUCKED - Slim Fit', 'PPrice': 'Rs.2,795.00', 'OnSale': True, 'SPrice': 'Rs.2,236.00', 'Color': 'solid-light-blue', 'Link': 'https://thecambridgeshop.com/collections/casual-shirt/products/f-s-untucked-cambridge-b5965', 'Fabric': '100% Cotton', 'Description': 'Designed to be worn untucked - Full sleeves slim fit shirt', 'Type': 'Casual Shirt', 'ImageName': ['https://drive.google.com/file/d/1jnQyRD1fmgl3LlAyRHmLNXBRSkuBvhob/view', 'https://drive.google.com/file/d/1fySmbJONzGFXFnDlqKXM5O5kSl4SbzsT/view', 'https://drive.google.com/file/d/1IBCWNF1rKxgORqO6SXvHjfc5hjkU95Vu/view', 'https://drive.google.com/file/d/1XAOdWgf-s_ApheY7LyCEtLsIKxtTZUcd/view']}
